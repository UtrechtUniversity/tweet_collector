# %% [markdown]
# # Extracting current Tweets

# %% [markdown]
# ## 1. Create options file
# Before you can filter out relevant Tweets, you first need to determine some 'option' arguments. These arguments are:
# 1) **query_params**: How do you want to filter the Tweets? <br>
# 2) **output_dir**: In what folder do you want to save the extracted Tweets? <br>
# 3) **output_file_name**: What name do you want to give the output file? <br>
# 4) **output_csv**: Do you want to save the output file as .csv or as .json (default)? <br>
#
# Define these arguments inside a dictionary and safe it as a .json file. To run the script, you only need to provide the path to this 'options' file as input argument.

# %%
https://developer.twitter.com/en/products/twitter-api/academic-research/application-info


# example of options.json
{"query_params": 
     {"query": "#EurovisionAgain lang:en has:geo -is:retweet",
         "max_results": 100,
         "end_time": "",
         "expansions": "geo.place_id",
         "tweet.fields": "id,author_id,created_at,text,entities,geo"
         },
     "output_dir": "output",
     "output_file_name": "extracted_tweets",
     "output_csv": "False"
 }
# Out:
# {'query_params': {'query': '#EurovisionAgain lang:en has:geo -is:retweet',
#   'max_results': 100,
#   'end_time': '',
#   'expansions': 'geo.place_id',
#   'tweet.fields': 'id,author_id,created_at,text,entities,geo'},
#  'output_dir': 'output',
#  'output_file_name': 'extracted_tweets',
#  'output_csv': 'False'}

# %% [markdown]
# *Note: if an argument is left empty (such as 'end_time'), this argument will not be included in the search filter.*

# %% [markdown]
# ### 1.1. Query parameters
# `query_params`
#
# There is an extensive list of arguments you can use to fine tune how you want to filter the recent Tweets. Some basic options are already listed in the `options.json` file, such as:
# * **query**: this is the most import argument as it specifies what the tweets will be filtered on (in this case the hashtag '#EurovisionAgain', being written in English, having a geo-location, and not being a retweet)
# * **max_results**: how many tweets do you want to extract?
# * **end_time**: most recent UTC timestamp to which the Tweets will be provided (format: `YYYY-MM-DDTHH:mm:ssZ`)
# * **expansions**: requests additional data objects that relate to the originally returned Tweets (in this case the geo-location of the tweet)
# * **tweet.fields**: which specific Tweet fields will be delivered in each returned Tweet object <br>
#
# For extra options have a look at: https://developer.twitter.com/en/docs/twitter-api/tweets/search/api-reference/get-tweets-search-recent

# %% [markdown]
# ### 1.2. Ouput directory
# `output_dir`
#
# This is the path to where the output file containing all extracted tweets, will be saved.
#
# For example: in the folder 'output'

# %% [markdown]
# ### 1.3. Ouput file name
# `output_file_name`
#
# This is the name the output file containing all extracted tweets will get.
#
# For example: 'extracted_tweets'

# %% [markdown]
# ### 1.4. Output file type
# `output_csv`
#
# When this option is "True", the output file will be saved as a .csv file in the output directory. If this option is "False" (or left empty), the output file will be saved as a. json file.
#
# For example: the file will now be saved in `output/extracted_tweets.json`

# %% [markdown]
# ## 2. Set Bearer Token
# Before you can connect with the Twitter server, you first need to save your Bearer Token as an environmental variable.
# To do this, open your terminal and use the following code (depending on your device):
#
# * **Mac**: `export "BEARER_TOKEN"="<insert_bearer_token_here>"`
# * **Windows**: `SET BEARER_TOKEN=<insert_bearer_token_here>`
#
# If this doesn't work, you can also run the following code inside this notebook/your Python console:

# %%
import os
os.environ['BEARER_TOKEN']='<insert_bearer_token_here>'

# %% [markdown]
# ## 3. Run script

# %%
from current_search import console

# %% [markdown]
# Run the following line in your terminal: <br> `python current_search.py -o options.json`

# %%
console('options.json')
# Out:
# {'data': [{'entities': {'annotations': [{'start': 7,
#       'end': 12,
#       'probability': 0.9294,
#       'type': 'Person',
#       'normalized_text': 'Carola'},
#      {'start': 37,
#       'end': 42,
#       'probability': 0.9475,
#       'type': 'Place',
#       'normalized_text': 'Sweden'}],
#     'urls': [{'start': 192,
#       'end': 215,
#       'url': 'https://t.co/4EwuOiWtiI',
#       'expanded_url': 'https://twitter.com/jrawson/status/1244015578953760768',
#       'display_url': 'twitter.com/jrawson/status…'}],
#     'hashtags': [{'start': 57, 'end': 68, 'tag': 'eurovision'},
#      {'start': 167, 'end': 183, 'tag': 'EurovisionAgain'},
#      {'start': 184, 'end': 191, 'tag': 'carola'}]},
#    'text': 'Seeing Carola presenting points from Sweden yesterday at #eurovision reminded me what a badass she is 😂 I fucking love this woman ♥ "Let me replant these daisies" 🌼 😂 #EurovisionAgain #carola https://t.co/4EwuOiWtiI',
#    'author_id': '4839655199',
#    'geo': {'place_id': '26b0db32cfda0432'},
#    'id': '1396576246537105415',
#    'created_at': '2021-05-23T21:18:18.000Z'},
#   {'entities': {'annotations': [{'start': 155,
#       'end': 163,
#       'probability': 0.4262,
#       'type': 'Place',
#       'normalized_text': 'Rotterdam'},
#      {'start': 182,
#       'end': 186,
#       'probability': 0.9591,
#       'type': 'Person',
#       'normalized_text': 'James'},
#      {'start': 188,
#       'end': 193,
#       'probability': 0.6281,
#       'type': 'Person',
#       'normalized_text': 'Jeangu'},
#      {'start': 195,
#       'end': 198,
#       'probability': 0.6696,
#       'type': 'Person',
#       'normalized_text': 'Blas'},
#      {'start': 200,
#       'end': 206,
#       'probability': 0.5752,
#       'type': 'Person',
#       'normalized_text': 'Jendrik'}],
#     'hashtags': [{'start': 37, 'end': 53, 'tag': 'EurovisionAgain'},
#      {'start': 260, 'end': 271, 'tag': 'Eurovision'}]},
#    'text': 'One of the things that stands out on #EurovisionAgain recordings is the crowd applauding when a country gets their first points in the voting process. The Rotterdam crowd supporting James/Jeangu/Blas/Jendrik despite the nulls reminds me of that. Good on them. #Eurovision',
#    'author_id': '1260279476870676485',
#    'geo': {'place_id': '7f15dd80ac78ef40'},
#    'id': '1396237735061594113',
#    'created_at': '2021-05-22T22:53:11.000Z'},
#   {'text': "Somehow I've never had the opportunity to watch #Eurovision before today! \nIt's quite a fun night actually! Anyone else watching? 😛\n\n#Eurovision2021 #EurovisionTop50 #eurovisiesongfestival #EurovisionPowerZone2021 #EurovisionSongContest #EurovisionAgain #EUROVISION",
#    'author_id': '170280254',
#    'geo': {'place_id': '2a0101ab07454619'},
#    'id': '1396210354661871618',
#    'entities': {'hashtags': [{'start': 48, 'end': 59, 'tag': 'Eurovision'},
#      {'start': 133, 'end': 148, 'tag': 'Eurovision2021'},
#      {'start': 149, 'end': 165, 'tag': 'EurovisionTop50'},
#      {'start': 166, 'end': 188, 'tag': 'eurovisiesongfestival'},
#      {'start': 189, 'end': 213, 'tag': 'EurovisionPowerZone2021'},
#      {'start': 214, 'end': 236, 'tag': 'EurovisionSongContest'},
#      {'start': 237, 'end': 253, 'tag': 'EurovisionAgain'},
#      {'start': 254, 'end': 265, 'tag': 'EUROVISION'}]},
#    'created_at': '2021-05-22T21:04:23.000Z'},
#   {'entities': {'annotations': [{'start': 3,
#       'end': 7,
#       'probability': 0.9259,
#       'type': 'Place',
#       'normalized_text': 'Italy'}],
#     'urls': [{'start': 110,
#       'end': 133,
#       'url': 'https://t.co/yRoriQtrkn',
#       'expanded_url': 'https://twitter.com/benjiw/status/1396208286991589377/photo/1',
#       'display_url': 'pic.twitter.com/yRoriQtrkn'}],
#     'hashtags': [{'start': 73, 'end': 80, 'tag': 'Allora'},
#      {'start': 81, 'end': 92, 'tag': 'Eurovision'},
#      {'start': 93, 'end': 109, 'tag': 'EurovisionAgain'}]},
#    'text': 'If Italy win we know what happens. We have a clear warning from history.\n#Allora #Eurovision #EurovisionAgain https://t.co/yRoriQtrkn',
#    'author_id': '14341032',
#    'geo': {'place_id': '3ddb10d62383799a'},
#    'id': '1396208286991589377',
#    'created_at': '2021-05-22T20:56:10.000Z'},
#   {'entities': {'annotations': [{'start': 78,
#       'end': 79,
#       'probability': 0.9294,
#       'type': 'Place',
#       'normalized_text': 'UK'}],
#     'mentions': [{'start': 149, 'end': 163, 'username': 'bbceurovision'}],
#     'hashtags': [{'start': 28, 'end': 39, 'tag': 'Eurovision'},
#      {'start': 101, 'end': 116, 'tag': 'Eurovision2021'},
#      {'start': 117, 'end': 133, 'tag': 'EurovisionAgain'},
#      {'start': 134, 'end': 144, 'tag': 'NilPoints'},
#      {'start': 145, 'end': 148, 'tag': 'UK'}]},
#    'text': 'Looking forward to watching #Eurovision can’t wait to see how many points the UK aren’t going to get #Eurovision2021 #EurovisionAgain #NilPoints #UK @bbceurovision',
#    'author_id': '802120822290792448',
#    'geo': {'place_id': '1c9ddd0025efc17b'},
#    'id': '1396180419259809799',
#    'created_at': '2021-05-22T19:05:26.000Z'},
#   {'text': "It's not #EurovisionAgain it's #eurovision2021 \n\n#den #Eurovision",
#    'author_id': '92016047',
#    'geo': {'place_id': '7ae9e2f2ff7a87cd'},
#    'id': '1395475083662086148',
#    'entities': {'hashtags': [{'start': 9, 'end': 25, 'tag': 'EurovisionAgain'},
#      {'start': 31, 'end': 46, 'tag': 'eurovision2021'},
#      {'start': 49, 'end': 53, 'tag': 'den'},
#      {'start': 54, 'end': 65, 'tag': 'Eurovision'}]},
#    'created_at': '2021-05-20T20:22:41.000Z'},
#   {'text': 'On this day in 2019 #DuncanLaurence writes #history with his victory #Eurovision with the ultimate song #Arcade. With this song he has no less than 1 billion streams at this moment! #EurovisionSongContest #ESC2021 #ESF2021 #EurovisionAgain #TeamDuncan @IlseDeLange @dunclaurence https://t.co/Vg6BL6WtFH',
#    'author_id': '1005708111741628419',
#    'geo': {'place_id': '03ee62e07f760312'},
#    'entities': {'mentions': [{'start': 252,
#       'end': 264,
#       'username': 'IlseDeLange'},
#      {'start': 265, 'end': 278, 'username': 'dunclaurence'}],
#     'urls': [{'start': 279,
#       'end': 302,
#       'url': 'https://t.co/Vg6BL6WtFH',
#       'expanded_url': 'https://twitter.com/TimLangeveld3/status/1395076845851316224/photo/1',
#       'display_url': 'pic.twitter.com/Vg6BL6WtFH'},
#      {'start': 279,
#       'end': 302,
#       'url': 'https://t.co/Vg6BL6WtFH',
#       'expanded_url': 'https://twitter.com/TimLangeveld3/status/1395076845851316224/photo/1',
#       'display_url': 'pic.twitter.com/Vg6BL6WtFH'},
#      {'start': 279,
#       'end': 302,
#       'url': 'https://t.co/Vg6BL6WtFH',
#       'expanded_url': 'https://twitter.com/TimLangeveld3/status/1395076845851316224/photo/1',
#       'display_url': 'pic.twitter.com/Vg6BL6WtFH'},
#      {'start': 279,
#       'end': 302,
#       'url': 'https://t.co/Vg6BL6WtFH',
#       'expanded_url': 'https://twitter.com/TimLangeveld3/status/1395076845851316224/photo/1',
#       'display_url': 'pic.twitter.com/Vg6BL6WtFH'}],
#     'hashtags': [{'start': 20, 'end': 35, 'tag': 'DuncanLaurence'},
#      {'start': 43, 'end': 51, 'tag': 'history'},
#      {'start': 69, 'end': 80, 'tag': 'Eurovision'},
#      {'start': 104, 'end': 111, 'tag': 'Arcade'},
#      {'start': 182, 'end': 204, 'tag': 'EurovisionSongContest'},
#      {'start': 205, 'end': 213, 'tag': 'ESC2021'},
#      {'start': 214, 'end': 222, 'tag': 'ESF2021'},
#      {'start': 223, 'end': 239, 'tag': 'EurovisionAgain'},
#      {'start': 240, 'end': 251, 'tag': 'TeamDuncan'}]},
#    'id': '1395076845851316224',
#    'created_at': '2021-05-19T18:00:13.000Z'},
#   {'text': 'A lot of acts getting their tits out to gain a few votes #Eurovision2021 #EuroSemi1 #eurovision #EurovisionAgain',
#    'author_id': '442708855',
#    'geo': {'place_id': '3cdad59a91d99400'},
#    'id': '1394754351273582596',
#    'entities': {'hashtags': [{'start': 57, 'end': 72, 'tag': 'Eurovision2021'},
#      {'start': 73, 'end': 83, 'tag': 'EuroSemi1'},
#      {'start': 84, 'end': 95, 'tag': 'eurovision'},
#      {'start': 96, 'end': 112, 'tag': 'EurovisionAgain'}]},
#    'created_at': '2021-05-18T20:38:45.000Z'},
#   {'entities': {'annotations': [{'start': 5,
#       'end': 11,
#       'probability': 0.9683,
#       'type': 'Place',
#       'normalized_text': 'Ireland'},
#      {'start': 24,
#       'end': 29,
#       'probability': 0.8934,
#       'type': 'Place',
#       'normalized_text': 'russia'}],
#     'urls': [{'start': 80,
#       'end': 103,
#       'url': 'https://t.co/ALNVokqhlN',
#       'expanded_url': 'https://twitter.com/Eurovision/status/1394730060096147456',
#       'display_url': 'twitter.com/Eurovision/sta…'}],
#     'hashtags': [{'start': 35, 'end': 46, 'tag': 'Eurovision'},
#      {'start': 47, 'end': 62, 'tag': 'Eurovision2021'},
#      {'start': 63, 'end': 79, 'tag': 'EurovisionAgain'}]},
#    'text': 'Vote Ireland!!!!!!! And russia too #Eurovision #Eurovision2021 #EurovisionAgain https://t.co/ALNVokqhlN',
#    'author_id': '162157097',
#    'geo': {'place_id': '7807880b17af73d8'},
#    'id': '1394739332532084742',
#    'created_at': '2021-05-18T19:39:04.000Z'},
#   {'text': '#ESC2021 #Eurovision #EurovisionAgain \n\nLET’S GOOOOOOOOOO!!!',
#    'author_id': '75472028',
#    'geo': {'place_id': '0073b76548e5984f'},
#    'id': '1394732337477296128',
#    'entities': {'hashtags': [{'start': 0, 'end': 8, 'tag': 'ESC2021'},
#      {'start': 9, 'end': 20, 'tag': 'Eurovision'},
#      {'start': 21, 'end': 37, 'tag': 'EurovisionAgain'}]},
#    'created_at': '2021-05-18T19:11:16.000Z'},
#   {'text': 'Thank you to #EurovisionAgain for turning me from a casual ironic #Eurovision watcher into a die hard serious Eurovision fan. 🙏🏻',
#    'author_id': '14341032',
#    'geo': {'place_id': '3ddb10d62383799a'},
#    'id': '1394731777189634051',
#    'entities': {'hashtags': [{'start': 13,
#       'end': 29,
#       'tag': 'EurovisionAgain'},
#      {'start': 66, 'end': 77, 'tag': 'Eurovision'}]},
#    'created_at': '2021-05-18T19:09:03.000Z'},
#   {'entities': {'annotations': [{'start': 55,
#       'end': 74,
#       'probability': 0.348,
#       'type': 'Other',
#       'normalized_text': 'Eurovision Semifinal'},
#      {'start': 99,
#       'end': 104,
#       'probability': 0.8146,
#       'type': 'Place',
#       'normalized_text': 'Cyprus'},
#      {'start': 110,
#       'end': 114,
#       'probability': 0.4385,
#       'type': 'Place',
#       'normalized_text': 'Malta'}],
#     'urls': [{'start': 166,
#       'end': 189,
#       'url': 'https://t.co/rKZm93qaaC',
#       'expanded_url': 'https://twitter.com/NikolaosGalanis/status/1394729974565908494/photo/1',
#       'display_url': 'pic.twitter.com/rKZm93qaaC'}],
#     'hashtags': [{'start': 121, 'end': 132, 'tag': 'Eurovision'},
#      {'start': 133, 'end': 148, 'tag': 'Eurovision2021'},
#      {'start': 149, 'end': 165, 'tag': 'EurovisionAgain'}]},
#    'text': '2 years since the last Eurovision show First!!!\n\nFirst Eurovision Semifinal on BBC4 now, Good luck Cyprus and Malta ! ❤\n\n#Eurovision #Eurovision2021 #EurovisionAgain https://t.co/rKZm93qaaC',
#    'author_id': '34685423',
#    'geo': {'place_id': '5524b796309058b5'},
#    'id': '1394729974565908494',
#    'created_at': '2021-05-18T19:01:53.000Z'},
#   {'text': 'Who are you voting for? #EUROVISION #Eurovision #EurovisionAgain #EurovisionSongContest2021 https://t.co/HzaPx9JeXt',
#    'author_id': '1283453882769780737',
#    'geo': {'place_id': '7f55e839e1715da2'},
#    'id': '1394729938226323460',
#    'entities': {'urls': [{'start': 92,
#       'end': 115,
#       'url': 'https://t.co/HzaPx9JeXt',
#       'expanded_url': 'https://twitter.com/nadine_pierre_/status/1394729938226323460/photo/1',
#       'display_url': 'pic.twitter.com/HzaPx9JeXt'}],
#     'hashtags': [{'start': 24, 'end': 35, 'tag': 'EUROVISION'},
#      {'start': 36, 'end': 47, 'tag': 'Eurovision'},
#      {'start': 48, 'end': 64, 'tag': 'EurovisionAgain'},
#      {'start': 65, 'end': 91, 'tag': 'EurovisionSongContest2021'}]},
#    'created_at': '2021-05-18T19:01:44.000Z'},
#   {'entities': {'annotations': [{'start': 13,
#       'end': 21,
#       'probability': 0.9798,
#       'type': 'Place',
#       'normalized_text': 'Australia'},
#      {'start': 37,
#       'end': 42,
#       'probability': 0.9515,
#       'type': 'Place',
#       'normalized_text': 'Europe'}],
#     'mentions': [{'start': 101, 'end': 117, 'username': 'actualmontaigne'}],
#     'urls': [{'start': 225,
#       'end': 248,
#       'url': 'https://t.co/GEtvtYUS3U',
#       'expanded_url': 'https://twitter.com/aussiestorm65/status/1394728447784587269/photo/1',
#       'display_url': 'pic.twitter.com/GEtvtYUS3U'}],
#     'hashtags': [{'start': 119, 'end': 133, 'tag': 'aussiestorm65'},
#      {'start': 134, 'end': 145, 'tag': 'Eurovision'},
#      {'start': 146, 'end': 161, 'tag': 'Eurovision2021'},
#      {'start': 162, 'end': 178, 'tag': 'EurovisionAgain'},
#      {'start': 179, 'end': 187, 'tag': 'ESC2021'},
#      {'start': 188, 'end': 195, 'tag': 'OpenUp'},
#      {'start': 196, 'end': 209, 'tag': 'Technicolour'},
#      {'start': 210, 'end': 224, 'tag': 'SBSEurovision'}]},
#    'text': 'Good morning Australia! Good evening Europe! It’s 4.52am and I’m ready to watch Eurovision! Let’s go @actualmontaigne \n#aussiestorm65 #Eurovision #Eurovision2021 #EurovisionAgain #ESC2021 #OpenUp #Technicolour #SBSEurovision https://t.co/GEtvtYUS3U',
#    'author_id': '2839532984',
#    'geo': {'place_id': '01552cf31a0d108e'},
#    'id': '1394728447784587269',
#    'created_at': '2021-05-18T18:55:49.000Z'},
#   {'text': 'ITS EUROVISION 2021 SEMI FINAL ONE TONIIGGHHTT #EurovisionAgain #OpenUp (open up but VACCINATED and SAFELY) https://t.co/o0diT93RMG',
#    'author_id': '724516748',
#    'geo': {'place_id': '60160252aeb7e3e5'},
#    'id': '1394653445278343174',
#    'entities': {'urls': [{'start': 108,
#       'end': 131,
#       'url': 'https://t.co/o0diT93RMG',
#       'expanded_url': 'https://twitter.com/AbbieTutt/status/1394653445278343174/photo/1',
#       'display_url': 'pic.twitter.com/o0diT93RMG'}],
#     'hashtags': [{'start': 47, 'end': 63, 'tag': 'EurovisionAgain'},
#      {'start': 64, 'end': 71, 'tag': 'OpenUp'}]},
#    'created_at': '2021-05-18T13:57:47.000Z'},
#   {'text': 'Okay, off to bed now! Alarm set for 4.30am! What? Wait? Why? ........ Because it’s EUROVISION TIME!!\n#Eurovision #Eurovision2021 #EurovisionAgain #ESC #OpenUp #SBSEurovision #Technicolour #ESC2021 https://t.co/zwsbpI1hZl',
#    'author_id': '2839532984',
#    'geo': {'place_id': '01552cf31a0d108e'},
#    'id': '1394609586242396160',
#    'entities': {'urls': [{'start': 197,
#       'end': 220,
#       'url': 'https://t.co/zwsbpI1hZl',
#       'expanded_url': 'https://twitter.com/aussiestorm65/status/1394609586242396160/photo/1',
#       'display_url': 'pic.twitter.com/zwsbpI1hZl'}],
#     'hashtags': [{'start': 101, 'end': 112, 'tag': 'Eurovision'},
#      {'start': 113, 'end': 128, 'tag': 'Eurovision2021'},
#      {'start': 129, 'end': 145, 'tag': 'EurovisionAgain'},
#      {'start': 146, 'end': 150, 'tag': 'ESC'},
#      {'start': 151, 'end': 158, 'tag': 'OpenUp'},
#      {'start': 159, 'end': 173, 'tag': 'SBSEurovision'},
#      {'start': 174, 'end': 187, 'tag': 'Technicolour'},
#      {'start': 188, 'end': 196, 'tag': 'ESC2021'}]},
#    'created_at': '2021-05-18T11:03:30.000Z'}],
#  'includes': {'places': [{'full_name': 'Walthamstow, London',
#     'id': '26b0db32cfda0432'},
#    {'full_name': 'Bristol, England', 'id': '7f15dd80ac78ef40'},
#    {'full_name': 'Nuneaton, England', 'id': '2a0101ab07454619'},
#    {'full_name': 'Bedford, England', 'id': '3ddb10d62383799a'},
#    {'full_name': 'Prestwood, South East', 'id': '1c9ddd0025efc17b'},
#    {'full_name': 'Edinburgh, Scotland', 'id': '7ae9e2f2ff7a87cd'},
#    {'full_name': 'Noordwijkerhout, Nederland', 'id': '03ee62e07f760312'},
#    {'full_name': 'Galway, Ireland', 'id': '3cdad59a91d99400'},
#    {'full_name': 'Guadalajara, Jalisco', 'id': '7807880b17af73d8'},
#    {'full_name': 'Sydney, New South Wales', 'id': '0073b76548e5984f'},
#    {'full_name': 'Brent, London', 'id': '5524b796309058b5'},
#    {'full_name': 'Camberwell, London', 'id': '7f55e839e1715da2'},
#    {'full_name': 'Geelong, Victoria', 'id': '01552cf31a0d108e'},
#    {'full_name': 'West Midlands, England', 'id': '60160252aeb7e3e5'}]},
#  'meta': {'newest_id': '1396576246537105415',
#   'oldest_id': '1394609586242396160',
#   'result_count': 16}}

# %%
import pandas as pd
output = console('options.json')
df = pd.DataFrame(output['data'])
try:
    df['Location'] = ""
    for i, id in enumerate(df['geo']):
        if id['place_id'] in str(output['includes']):
            location = [location['full_name']
                        for location in output['includes']['places'] if id['place_id'] == location['id']][0]
            df.loc[i, 'Location'] = location
except KeyError:
    pass
df
# Out:
#                                                  text                   id  \
# 0   Seeing Carola presenting points from Sweden ye...  1396576246537105415
# 1   One of the things that stands out on #Eurovisi...  1396237735061594113
# 2   Somehow I've never had the opportunity to watc...  1396210354661871618
# 3   If Italy win we know what happens. We have a c...  1396208286991589377
# 4   Looking forward to watching #Eurovision can’t ...  1396180419259809799
# 5   It's not #EurovisionAgain it's #eurovision2021...  1395475083662086148
# 6   On this day in 2019 #DuncanLaurence writes #hi...  1395076845851316224
# 7   A lot of acts getting their tits out to gain a...  1394754351273582596
# 8   Vote Ireland!!!!!!! And russia too #Eurovision...  1394739332532084742
# 9   #ESC2021 #Eurovision #EurovisionAgain \n\nLET’...  1394732337477296128
# 10  Thank you to #EurovisionAgain for turning me f...  1394731777189634051
# 11  2 years since the last Eurovision show First!!...  1394729974565908494
# 12  Who are you voting for? #EUROVISION #Eurovisio...  1394729938226323460
# 13  Good morning Australia! Good evening Europe! I...  1394728447784587269
# 14  ITS EUROVISION 2021 SEMI FINAL ONE TONIIGGHHTT...  1394653445278343174
# 15  Okay, off to bed now! Alarm set for 4.30am! Wh...  1394609586242396160
#
#                                  geo                created_at  \
# 0   {'place_id': '26b0db32cfda0432'}  2021-05-23T21:18:18.000Z
# 1   {'place_id': '7f15dd80ac78ef40'}  2021-05-22T22:53:11.000Z
# 2   {'place_id': '2a0101ab07454619'}  2021-05-22T21:04:23.000Z
# 3   {'place_id': '3ddb10d62383799a'}  2021-05-22T20:56:10.000Z
# 4   {'place_id': '1c9ddd0025efc17b'}  2021-05-22T19:05:26.000Z
# 5   {'place_id': '7ae9e2f2ff7a87cd'}  2021-05-20T20:22:41.000Z
# 6   {'place_id': '03ee62e07f760312'}  2021-05-19T18:00:13.000Z
# 7   {'place_id': '3cdad59a91d99400'}  2021-05-18T20:38:45.000Z
# 8   {'place_id': '7807880b17af73d8'}  2021-05-18T19:39:04.000Z
# 9   {'place_id': '0073b76548e5984f'}  2021-05-18T19:11:16.000Z
# 10  {'place_id': '3ddb10d62383799a'}  2021-05-18T19:09:03.000Z
# 11  {'place_id': '5524b796309058b5'}  2021-05-18T19:01:53.000Z
# 12  {'place_id': '7f55e839e1715da2'}  2021-05-18T19:01:44.000Z
# 13  {'place_id': '01552cf31a0d108e'}  2021-05-18T18:55:49.000Z
# 14  {'place_id': '60160252aeb7e3e5'}  2021-05-18T13:57:47.000Z
# 15  {'place_id': '01552cf31a0d108e'}  2021-05-18T11:03:30.000Z
#
#                                              entities            author_id  \
# 0   {'hashtags': [{'start': 57, 'end': 68, 'tag': ...           4839655199
# 1   {'hashtags': [{'start': 37, 'end': 53, 'tag': ...  1260279476870676485
# 2   {'hashtags': [{'start': 48, 'end': 59, 'tag': ...            170280254
# 3   {'hashtags': [{'start': 73, 'end': 80, 'tag': ...             14341032
# 4   {'hashtags': [{'start': 28, 'end': 39, 'tag': ...   802120822290792448
# 5   {'hashtags': [{'start': 9, 'end': 25, 'tag': '...             92016047
# 6   {'hashtags': [{'start': 20, 'end': 35, 'tag': ...  1005708111741628419
# 7   {'hashtags': [{'start': 57, 'end': 72, 'tag': ...            442708855
# 8   {'hashtags': [{'start': 35, 'end': 46, 'tag': ...            162157097
# 9   {'hashtags': [{'start': 0, 'end': 8, 'tag': 'E...             75472028
# 10  {'hashtags': [{'start': 13, 'end': 29, 'tag': ...             14341032
# 11  {'hashtags': [{'start': 121, 'end': 132, 'tag'...             34685423
# 12  {'hashtags': [{'start': 24, 'end': 35, 'tag': ...  1283453882769780737
# 13  {'hashtags': [{'start': 119, 'end': 133, 'tag'...           2839532984
# 14  {'hashtags': [{'start': 47, 'end': 63, 'tag': ...            724516748
# 15  {'hashtags': [{'start': 101, 'end': 112, 'tag'...           2839532984
#
#                       Location
# 0          Walthamstow, London
# 1             Bristol, England
# 2            Nuneaton, England
# 3             Bedford, England
# 4        Prestwood, South East
# 5          Edinburgh, Scotland
# 6   Noordwijkerhout, Nederland
# 7              Galway, Ireland
# 8         Guadalajara, Jalisco
# 9      Sydney, New South Wales
# 10            Bedford, England
# 11               Brent, London
# 12          Camberwell, London
# 13           Geelong, Victoria
# 14      West Midlands, England
# 15           Geelong, Victoria

# %%
output['meta']
# Out:
# {'newest_id': '1396576246537105415',
#  'oldest_id': '1394609586242396160',
#  'result_count': 16}
